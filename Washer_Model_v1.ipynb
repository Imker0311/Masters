# %%
import numpy as np

# Input parameters
Cyi = np.array([1.25, 1.25, 1.25, 1.25]) / 100
Cyd = np.array([12, 12, 13, 14]) / 100

xi = np.array([15.59, 7.29, 2.62, 0.96]) / 100
xs = np.array([7, 2.5, 0.9, 0]) / 100
xf = np.array([15, 7, 2.5, 0.9]) / 100
xd = np.array([10.12, 3.77, 1.58, 0.3]) / 100
xr = np.array([15, 7, 2.5, 0.9]) / 100

Li = np.array([79, 79, 79, 79])
Ls = np.array([10.33, 10.33, 9.69, 9.14])
Lf = np.array([82, 82, 82, 82])
Ld = np.array([7.33, 7.33, 6.69, 6.14])
Lr = np.array([72.31, 71.67, 71.67, 72.31])

Lb = 6.69
Cyb = 13
xb = 0.22
